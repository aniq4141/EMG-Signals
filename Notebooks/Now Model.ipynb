# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("all_data.csv")
data.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          587      579       0.72       0
# 1          589      592       0.72       0
# 2          605      603       0.74       0
# 3          624      627       0.76       0
# 4          622      622       0.76       0

# %%
a = data.iloc[:200, :]
b = data.iloc[200:400, :]
c = data.iloc[400:600, :]
d = data.iloc[600:800, :]

# %%
a.tail()
# Out:
#      AnalogValue  Density  Amplitude  Result
# 195          498      499       0.61       0
# 196          499      501       0.61       0
# 197          498      496       0.61       0
# 198          491      490       0.60       0
# 199          483      482       0.59       0

# %%
b.tail()
# Out:
#      AnalogValue  Density  Amplitude  Result
# 595          281      278       0.34       2
# 596          274      265       0.33       2
# 597          267      269       0.33       2
# 598          266      267       0.32       2
# 599          252      256       0.31       2

# %%
plt.scatter(a["AnalogValue"], a["Amplitude"], color = "green", marker = "+")
plt.scatter(b["AnalogValue"], b["Amplitude"], color = "blue", marker = ".")
plt.xlabel("Analgo Values")
plt.ylabel("Amplitude")
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the subplots
fig, axes = plt.subplots(4, 3, figsize=(12, 16))

# Plot a & b
axes[0, 0].scatter(a["AnalogValue"], a["Amplitude"], color="green", marker="+")
axes[0, 0].scatter(b["AnalogValue"], b["Amplitude"], color="blue", marker=".")
axes[0, 0].set_title('a & b')
axes[0, 0].set_xlabel('a')
axes[0, 0].set_ylabel('b')

# Plot a & c
axes[0, 1].scatter(a["AnalogValue"], a["Amplitude"], color="green", marker="+")
axes[0, 1].scatter(c["AnalogValue"], c["Amplitude"], color="blue", marker=".")
axes[0, 1].set_title('a & c')
axes[0, 1].set_xlabel('a')
axes[0, 1].set_ylabel('c')

# Plot a & d
axes[0, 2].scatter(a["AnalogValue"], a["Amplitude"], color="green", marker="+")
axes[0, 2].scatter(d["AnalogValue"], d["Amplitude"], color="blue", marker=".")
axes[0, 2].set_title('a & d')
axes[0, 2].set_xlabel('a')
axes[0, 2].set_ylabel('d')

# Plot b & a
axes[1, 0].scatter(b["AnalogValue"], b["Amplitude"], color="green", marker="+")
axes[1, 0].scatter(a["AnalogValue"], a["Amplitude"], color="blue", marker=".")
axes[1, 0].set_title('b & a')
axes[1, 0].set_xlabel('b')
axes[1, 0].set_ylabel('a')

# Plot b & c
axes[1, 1].scatter(b["AnalogValue"], b["Amplitude"], color="green", marker="+")
axes[1, 1].scatter(c["AnalogValue"], c["Amplitude"], color="blue", marker=".")
axes[1, 1].set_title('b & c')
axes[1, 1].set_xlabel('b')
axes[1, 1].set_ylabel('c')

# Plot b & d
axes[1, 2].scatter(b["AnalogValue"], b["Amplitude"], color="green", marker="+")
axes[1, 2].scatter(d["AnalogValue"], d["Amplitude"], color="blue", marker=".")
axes[1, 2].set_title('b & d')
axes[1, 2].set_xlabel('b')
axes[1, 2].set_ylabel('d')

# Plot c & a
axes[2, 0].scatter(c["AnalogValue"], c["Amplitude"], color="green", marker="+")
axes[2, 0].scatter(a["AnalogValue"], a["Amplitude"], color="blue", marker=".")
axes[2, 0].set_title('c & a')
axes[2, 0].set_xlabel('c')
axes[2, 0].set_ylabel('a')

# Plot c & b
axes[2, 1].scatter(c["AnalogValue"], c["Amplitude"], color="green", marker="+")
axes[2, 1].scatter(b["AnalogValue"], b["Amplitude"], color="blue", marker=".")
axes[2, 1].set_title('c & b')
axes[2, 1].set_xlabel('c')
axes[2, 1].set_ylabel('b')

# Plot c & d
axes[2, 2].scatter(c["AnalogValue"], c["Amplitude"], color="green", marker="+")
axes[2, 2].scatter(d["AnalogValue"], d["Amplitude"], color="blue", marker=".")
axes[2, 2].set_title('c & d')
axes[2, 2].set_xlabel('c')
axes[2, 2].set_ylabel('d')

# Plot d & a
axes[3, 0].scatter(d["AnalogValue"], d["Amplitude"], color="green", marker="+")
axes[3, 0].scatter(a["AnalogValue"], a["Amplitude"], color="blue", marker=".")
axes[3, 0].set_title('d & a')
axes[3, 0].set_xlabel('d')
axes[3, 0].set_ylabel('a')

# Plot d & b
axes[3, 1].scatter(d["AnalogValue"], d["Amplitude"], color="green", marker="+")
axes[3, 1].scatter(b["AnalogValue"], b["Amplitude"], color="blue", marker=".")
axes[3, 1].set_title('d & b')
axes[3, 1].set_xlabel('d')
axes[3, 1].set_ylabel('b')

# Plot d & c
axes[3, 2].scatter(d["AnalogValue"], d["Amplitude"], color="green", marker="+")
axes[3, 2].scatter(c["AnalogValue"], c["Amplitude"], color="blue", marker=".")
axes[3, 2].set_title('d & c')
axes[3, 2].set_xlabel('d')
axes[3, 2].set_ylabel('c')

# Adjust spacing between subplots
plt.tight_layout()

# Display the figure
plt.show()
