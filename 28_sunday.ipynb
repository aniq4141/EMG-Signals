# %%
import pandas as pd
import numpy as np

# %%
df0 = pd.read_csv("right/right.csv")
df1 = pd.read_csv("right/right1.csv")
df2 = pd.read_csv("right/right_new.csv")

# %%
df0.head()
# Out:
#    Unnamed: 0  AnalogValue  Density  Amplitude  Result
# 0           0          396      396       0.48       2
# 1           1          405      407       0.49       2
# 2           2          423      423       0.52       2
# 3           3          413      411       0.50       2
# 4           4          405      402       0.49       2

# %%
df0 = df0.drop("Unnamed: 0", axis = 1)

# %%
df0["Result"] = df0["Result"].replace(2, 0)
df0.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          396      396       0.48       0
# 1          405      407       0.49       0
# 2          423      423       0.52       0
# 3          413      411       0.50       0
# 4          405      402       0.49       0

# %%
df1 = df1.drop("Unnamed: 0", axis = 1)
df1.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          249      246       0.30       2
# 1          241      247       0.29       2
# 2          243      241       0.30       2
# 3          238      238       0.29       2
# 4          239      240       0.29       2

# %%
df1["Result"] = df1["Result"].replace(2, 0)
df1.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          249      246       0.30       0
# 1          241      247       0.29       0
# 2          243      241       0.30       0
# 3          238      238       0.29       0
# 4          239      240       0.29       0

# %%
df2["Result"] = 0
df2.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0         1195     1194       1.46       0
# 1         1197     1198       1.46       0
# 2         1200     1211       1.47       0
# 3         1264     1265       1.54       0
# 4         1264     1264       1.54       0

# %%
df2.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0         1195     1194       1.46       0
# 1         1197     1198       1.46       0
# 2         1200     1211       1.47       0
# 3         1264     1265       1.54       0
# 4         1264     1264       1.54       0

# %%
data_right = pd.concat([df0,df1,df2])
data_right.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          396      396       0.48       0
# 1          405      407       0.49       0
# 2          423      423       0.52       0
# 3          413      411       0.50       0
# 4          405      402       0.49       0

# %%
data_right.to_csv("right/all_right.csv")

# %%
data_right.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          396      396       0.48       0
# 1          405      407       0.49       0
# 2          423      423       0.52       0
# 3          413      411       0.50       0
# 4          405      402       0.49       0

# %%
df3 = pd.read_csv("left/left1.csv")
df4 = pd.read_csv("left/left2.csv")
df5 = pd.read_csv("left/left_new.csv")

# %%
df3.head()
# Out:
#    Unnamed: 0  AnalogValue  Density  Amplitude  Result
# 0           0          688      686       0.84       3
# 1           1          692      695       0.84       3
# 2           2          737      739       0.90       3
# 3           3          736      736       0.90       3
# 4           4          732      723       0.89       3

# %%
df3 = df3.drop("Unnamed: 0", axis = 1)
df3.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          688      686       0.84       3
# 1          692      695       0.84       3
# 2          737      739       0.90       3
# 3          736      736       0.90       3
# 4          732      723       0.89       3

# %%
df3["Result"] = df3["Result"].replace(3,1)
df3.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          688      686       0.84       1
# 1          692      695       0.84       1
# 2          737      739       0.90       1
# 3          736      736       0.90       1
# 4          732      723       0.89       1

# %%
# df4 = df4.drop("Unnamed: 0", axis=1)
df4["Result"] = df4["Result"].replace(3.0, 1)
df4.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          623    627.0       0.76     1.0
# 1          628    629.0       0.77     1.0
# 2          621    621.0       0.76     1.0
# 3          621    621.0       0.76     1.0
# 4          608    617.0       0.74     1.0

# %%
# Convert float column to int
df4 = df4.drop("Result", axis =1 )
df4["Result"] = 1
df4.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          623    627.0       0.76       1
# 1          628    629.0       0.77       1
# 2          621    621.0       0.76       1
# 3          621    621.0       0.76       1
# 4          608    617.0       0.74       1

# %%
df5["Result"] = 1
df5.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          996      997       1.22       1
# 1          996     1002       1.22       1
# 2          991      995       1.21       1
# 3          976      978       1.19       1
# 4          976      976       1.19       1

# %%
data_left = pd.concat([df3,df4,df5])
data_left.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          688    686.0       0.84       1
# 1          692    695.0       0.84       1
# 2          737    739.0       0.90       1
# 3          736    736.0       0.90       1
# 4          732    723.0       0.89       1

# %%
data_left.tail()
# Out:
#       AnalogValue  Density  Amplitude  Result
# 1995          990    987.0       1.21       1
# 1996          970    975.0       1.18       1
# 1997          966    965.0       1.18       1
# 1998          961    964.0       1.17       1
# 1999          976    981.0       1.19       1

# %%
data_left.to_csv("left/all_left.csv")

# %%
all_right.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 all_right.head()
#
# NameError: name 'all_right' is not defined

# %%
data = pd.concat([data_right,data_left])
data.tail()
# Out:
#       AnalogValue  Density  Amplitude  Result
# 1995          990    987.0       1.21       1
# 1996          970    975.0       1.18       1
# 1997          966    965.0       1.18       1
# 1998          961    964.0       1.17       1
# 1999          976    981.0       1.19       1

# %%
data = data.reset_index(drop = True)
data.tail()
# Out:
#       AnalogValue  Density  Amplitude  Result
# 4895          990    987.0       1.21       1
# 4896          970    975.0       1.18       1
# 4897          966    965.0       1.18       1
# 4898          961    964.0       1.17       1
# 4899          976    981.0       1.19       1

# %%
all_right = pd.read_csv("right/all_right.csv")
all_left = pd.read_csv("left/all_left.csv")
all_right.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          396      396       0.48       0
# 1          405      407       0.49       0
# 2          423      423       0.52       0
# 3          413      411       0.50       0
# 4          405      402       0.49       0

# %%
all_right = all_right.iloc[:2000, :]
all_left = all_left.iloc[:2000, :]

# %%
print(len(all_right))
print(len(all_left))
# Out:
# 2000
# 2000

# %%
data = pd.concat([all_right,all_left])
data.head()
# Out:
#    AnalogValue  Density  Amplitude  Result  Unnamed: 0
# 0          396    396.0       0.48       0         NaN
# 1          405    407.0       0.49       0         NaN
# 2          423    423.0       0.52       0         NaN
# 3          413    411.0       0.50       0         NaN
# 4          405    402.0       0.49       0         NaN

# %%
data = data.reset_index(drop = True)
data.tail()
# Out:
#       AnalogValue  Density  Amplitude  Result  Unnamed: 0
# 3995         1005   1007.0       1.23       1      1295.0
# 3996         1002   1008.0       1.22       1      1296.0
# 3997          999   1003.0       1.22       1      1297.0
# 3998          983    980.0       1.20       1      1298.0
# 3999          967    971.0       1.18       1      1299.0

# %%
data = data.drop("Unnamed: 0", axis = 1)
data.tail()
# Out:
#       AnalogValue  Density  Amplitude  Result
# 3995         1005   1007.0       1.23       1
# 3996         1002   1008.0       1.22       1
# 3997          999   1003.0       1.22       1
# 3998          983    980.0       1.20       1
# 3999          967    971.0       1.18       1

# %%
data.to_csv("right_left.csv")

# %%
all_right.head()
# Out:
#    AnalogValue  Density  Amplitude  Result
# 0          396      396       0.48       0
# 1          405      407       0.49       0
# 2          423      423       0.52       0
# 3          413      411       0.50       0
# 4          405      402       0.49       0

# %%
import matplotlib.pyplot as plt

plt.scatter(all_right["AnalogValue"], all_right["Density"], color="green", marker="+")
plt.scatter(all_left["AnalogValue"], all_left["Density"], color="blue", marker=".")
plt.xlabel("Analog Value")
plt.ylabel("Density")
plt.title("Scatter Plot")
plt.show()
